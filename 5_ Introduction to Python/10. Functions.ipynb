# %% [markdown]
# **Functions**
#
#
# 1.  Hello World Function
# 2.  First Name/Last Name in Function
# 3.  Print even no in list (0-10)
# 4.  Square the numbers between 0-9
# 5. Addition
# 6. Step Function

# %%
def Hello ():
  print("Hello world")

Hello()

# %%
def name(Fname,Lname):
  Fname = str(input())
  Lname = str(input())
  print(Fname+Lname)
name(a,b)

# %%
def predict(x):
  if x%2==0:
    print('Even')
  elif x%2!=0:
    print('Odd')

a = list(range(10))
for i in a:
  predict(i)

# %% [markdown]
# **Task**
# Square of the numbers using function

# %%
def square(x):
  z = x**2
  return z
print(square(4))
# Out:
# 16

# %% [markdown]
# **Task**
# Sum of two numbers using function

# %%
def sum(a,b):
  res=a+b
  return res
print(sum(5,5))

# %% [markdown]
# **Step Function**

# %%
def step(z):
  if z>0:
    print("Fire")
  else:
    print("Dont Fire")
a = list(range(-5,5))
for i in a:
  step(i)
# Out:
# Dont Fire
# Dont Fire
# Dont Fire
# Dont Fire
# Dont Fire
# Dont Fire
# Fire
# Fire
# Fire
# Fire

# %% [markdown]
# **Loss Function Implementations**
#
#
# 1.   **Mean Square Error**

# %%
import numpy as np
i = 8
y = 10
def meansquare(a,b):
  c=np.square(a-b)
  print(c)
  
meansquare(8,10)
# Out:
# 4
